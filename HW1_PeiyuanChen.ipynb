# %% [markdown]
# # Homework 1: Project Report

# %% [markdown]
# ### **Table of Contents**

# %% [markdown]
# 1. [Introduction](#introduction)
#
# 2. [Project Overview](#project-overview)
#    - [Data Acquisition](#data-acquisition)
#    - [Exploratory Data Analysis (EDA)](#exploratory-data-analysis-eda)
#    - [Predictive Modeling](#predictive-modeling)
#
# 3. [Key Findings](#key-findings)
# 4. [Conclusion](#conclusion)
# 5. [Question 6 Answer](#question-6-answer)

# %% [markdown]
# ## 1. Introduction <a class="anchor" id="bullet1"></a>
# In this report, I will look at the [Singapore Condo Rental Market Analysis](https://github.com/kennethleungty/Singapore-Condo-Rental-Market-Analysis) project by Kenneth Leung. This project provides an in-depth examination of Singapore's condominium rental market, utilizing data scraping, analysis, and machine learning techniques to predict rental prices.

# %% [markdown]
# ## 2. Project Review<a class="anchor" id="bullet1"></a>
# The project is structured into three main phases:
#
# <a class="anchor" id="data-acquisition"></a>
# ## - Data Acquisition
#
# - **Web Scraping:** Data was collected from online property listings to gather information on rental prices, locations, and property features.
#
# <a class="anchor" id="exploratory-data-analysis-eda"></a>
# ## - Exploratory Data Analysis (EDA)
#
# - **Data Cleaning:** Handling missing values and outliers to ensure data quality.
# - **Visualization:** Generating regression plots to understand the factors influencing the rental prices in Singapore.
# ![image.png](attachment:image.png)
#
# <a class="anchor" id="predictive-modeling"></a>
# ## - Predictive Modeling
#
# - **Machine Learning Models:** Implementation of various regression models, including:
#   - Linear Regression
#   - Random Forest Regressor
#   - XGBoost Regressor
#   - LightGBM Regressor
#   - CatBoost Regressor
#
# ---
#
# <a class="anchor" id="key-findings"></a>

# %% [markdown]
# <a class="anchor" id="key-findings"></a>
# # **3. Key Findings**
#
# - **Feature Importance:**
# Factors such as location, floor area, and proximity to amenities significantly influence rental prices.
#
# - **Model Performance:**
# Ensemble models like Random Forest and XGBoost provided better predictive accuracy compared to linear models.

# %% [markdown]
# <a class="anchor" id="conclusion"></a>
# # **4. Conclusion**
#
# This [Singapore Condo Rental Market Analysis](https://github.com/kennethleungty/Singapore-Condo-Rental-Market-Analysis) project has done well in exploring the determinants of rental prices in Singapore's condominium market. By leveraging data analytics and machine learning, it aids in understanding market dynamics and assists stakeholders in making informed decisions.

# %% [markdown]
# <a class="anchor" id="key-findings"></a>
# # **5. Question 6 Answer**
#
# **#Question#**: *When you looked at your commit history on either GitHub or GitHub Desktop for the Jupyter Notebook, did the code look familiar? What about the code for the python script you made? Why did the code for Jupyter Notebook seem foreign?*
#
# **Answer**: *When I looked at the commit history for the Jupyter Notebook, the code felt surprisingly unfamiliar. In contrast, the Python script was much easier to follow because it’s laid out in a simple, linear format. I was initially confused about why the notebook’s commit history seemed so cluttered, but after digging a bit deeper, I realized it’s because Jupyter Notebooks are saved in JSON format. This doesn’t just include the code and markdown cells—it also stores metadata, outputs, and execution counts. All of that extra information made the commit history look overwhelming, almost like trying to read through noise. Understanding this helped me make sense of why the Python script felt clearer while the notebook seemed more complex.*
